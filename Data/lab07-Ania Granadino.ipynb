# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Data = pd.read_csv("Datos_Tea.csv")
Data
# Out:
#         day  month  year            Time  Rain
# 0        13      8  2015  03:30:00 a. m.   0.0
# 1        13      8  2015  04:00:00 a. m.   0.0
# 2        13      8  2015  04:30:00 a. m.   0.0
# 3        13      8  2015  05:00:00 a. m.   0.0
# 4        13      8  2015  05:30:00 a. m.   0.0
# ...     ...    ...   ...             ...   ...
# 224741    6      6  2022  02:00:00 p. m.   0.0
# 224742    6      6  2022  02:10:00 p. m.   0.0
# 224743    6      6  2022  02:20:00 p. m.   0.0
# 224744    6      6  2022  02:30:00 p. m.   0.0
# 224745    6      6  2022  02:40:00 p. m.   0.0
#
# [224746 rows x 5 columns]

# %%
Año = Data[Data.year == 2021]
Año
# Out:
#         day  month  year            Time  Rain
# 151157    1      1  2021  12:00:00 a. m.   0.0
# 151158    1      1  2021  12:10:00 a. m.   0.0
# 151159    1      1  2021  12:20:00 a. m.   0.0
# 151160    1      1  2021  12:30:00 a. m.   0.0
# 151161    1      1  2021  12:40:00 a. m.   0.0
# ...     ...    ...   ...             ...   ...
# 203258   31     12  2021  11:10:00 p. m.   0.0
# 203259   31     12  2021  11:20:00 p. m.   0.0
# 203260   31     12  2021  11:30:00 p. m.   0.0
# 203261   31     12  2021  11:40:00 p. m.   0.0
# 203262   31     12  2021  11:50:00 p. m.   0.0
#
# [52106 rows x 5 columns]

# %%
fig, ax = plt.subplots(figsize=(10,5))
sns.heatmap(Año.groupby(["day","month"])["Rain"].sum().unstack("month",fill_value=0),cmap="Reds")
# Out:
# <AxesSubplot:xlabel='month', ylabel='day'>

# %%
fig, ax = plt.subplots(figsize=(10,5))
sns.heatmap(Data.groupby(["day","month"])["Rain"].sum().unstack("month",fill_value=0),cmap="Spectral")
# Out:
# <AxesSubplot:xlabel='month', ylabel='day'>

# %%
fig, ax = plt.subplots(figsize=(15,7))
sns.heatmap(Data.groupby(["year","month"])["Rain"].sum().unstack("month",fill_value=0), annot=True,fmt='2g' ,cmap="Spectral")
# Out:
# <AxesSubplot:xlabel='month', ylabel='year'>

# %%
Año
# Out:
#         day  month  year            Time  Rain
# 151157    1      1  2021  12:00:00 a. m.   0.0
# 151158    1      1  2021  12:10:00 a. m.   0.0
# 151159    1      1  2021  12:20:00 a. m.   0.0
# 151160    1      1  2021  12:30:00 a. m.   0.0
# 151161    1      1  2021  12:40:00 a. m.   0.0
# ...     ...    ...   ...             ...   ...
# 203258   31     12  2021  11:10:00 p. m.   0.0
# 203259   31     12  2021  11:20:00 p. m.   0.0
# 203260   31     12  2021  11:30:00 p. m.   0.0
# 203261   31     12  2021  11:40:00 p. m.   0.0
# 203262   31     12  2021  11:50:00 p. m.   0.0
#
# [52106 rows x 5 columns]

# %%
new_data = Data[["month","year","Rain"]]
new_data
# Out:
#         month  year  Rain
# 0           8  2015   0.0
# 1           8  2015   0.0
# 2           8  2015   0.0
# 3           8  2015   0.0
# 4           8  2015   0.0
# ...       ...   ...   ...
# 224741      6  2022   0.0
# 224742      6  2022   0.0
# 224743      6  2022   0.0
# 224744      6  2022   0.0
# 224745      6  2022   0.0
#
# [224746 rows x 3 columns]

# %%
fig, ax = plt.subplots(figsize=(10,5))
sns.heatmap(Año.groupby(["year","month"])["Rain"].sum().unstack("month",fill_value=0),annot=True, fmt='2g', cmap="Reds")
# Out:
# <AxesSubplot:xlabel='month', ylabel='year'>

# %%
fil_data = pd.read_csv("datos_filtrados.csv")
fil_data
# Out:
#         month  year  Rain  Total_m3  area_m2
# 0           8  2015   0.0       0.0        1
# 1           8  2015   0.0       0.0        1
# 2           8  2015   0.0       0.0        1
# 3           8  2015   0.0       0.0        1
# 4           8  2015   0.0       0.0        1
# ...       ...   ...   ...       ...      ...
# 224741      6  2022   0.0       0.0        1
# 224742      6  2022   0.0       0.0        1
# 224743      6  2022   0.0       0.0        1
# 224744      6  2022   0.0       0.0        1
# 224745      6  2022   0.0       0.0        1
#
# [224746 rows x 5 columns]

# %%
fig, ax = plt.subplots(figsize=(15,7))
plt.title("Grafica de precipitacion por metro cubico entre un metro cuadrado ")
sns.heatmap(fil_data.groupby(["year","month"])["Total_m3"].sum().unstack("month",fill_value=0), annot=True,fmt='2g' ,cmap="Spectral")
# Out:
# <AxesSubplot:title={'center':'Grafica de precipitacion por metro cubico entre un metro cuadrado '}, xlabel='month', ylabel='year'>
